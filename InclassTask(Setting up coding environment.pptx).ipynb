# %% [markdown]
# Name: DDEMBE GALIWANGO HUMPHREY
# Student Number: 2501902230
# Registration Number: 2025/DSMA/DAY/2230/G

# %%
# program to create a dataset of 5 students with their scores.
students = {
    "Alice": 85,
    "Bob": 92,
    "Charlie": 78,
    "David": 90,
    "Eva": 88
}

# Print the dataset
print("Student Scores Dataset:", students)
# Out:
# Student Scores Dataset: {'Alice': 85, 'Bob': 92, 'Charlie': 78, 'David': 90, 'Eva': 88}
