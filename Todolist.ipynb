# %% [markdown]
# Name: DDEMBE GALIWANGO HUMPHREY
# Student Number: 2501902230
# Registration Number: 2025/DSMA/DAY/2230/G

# %%
# Todo list in the morning program
todo_list = ["Wake up", "Brush teeth", "Have breakfast", "Go for a walk", "Read a book"]
for task in todo_list:
    print("Task:", task)
# Out:
# Task: Wake up
# Task: Brush teeth
# Task: Have breakfast
# Task: Go for a walk
# Task: Read a book
