# %% [markdown]
# Name: DDEMBE GALIWANGO HUMPHREY
# Student Number: 2501902230
# Registration Number: 2025/DSMA/DAY/2230/G

# %%
#Consider a given age as 64. Check for the following conditions. 
# If age is less than 20, return ‘You are pretty young’ 
# If age is between 20 and 40, return ‘The journey has just begun’ 
# If age is between 40 and 60, return ‘Huh! Life is pretty good here’ 
# If age is between 60 and 80, return, ‘Oops! My hair is dark no more’ 
# If age is greater than 80, return ‘My eyes have seen it all’ 

# Program to check age conditions
age = 64
if age < 20:
    print("You are pretty young")
elif 20 <= age <= 40:
    print("The journey has just begun")
elif 40 < age <= 60:
    print("Huh! Life is pretty good here")
elif 60 < age <= 80:
    print("Oops! My hair is dark no more")
else:
    print("My eyes have seen it all")
# Out:
# Oops! My hair is dark no more
